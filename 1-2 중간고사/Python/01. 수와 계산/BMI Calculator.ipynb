# %%
print("Hello World")
# Out:
# Hello World

# %%
weight = eval(input("weight(kg): "))
height = eval(input("height(cm): "))
bmi = weight/(height/100)**2
print(f"BMI: {bmi:2f}")
# Out:
# weight(kg): 68
# height(cm): 178
# BMI: 21.461937
